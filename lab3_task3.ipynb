# %%
from collections import defaultdict
import itertools
import numpy as np

# %%
def read_words_base_forms():
    words_base_forms = defaultdict(lambda: [])
    with open("base_forms.txt", "r") as fstream:
        bases_words = map(lambda x: x.split(";")[0:2], fstream.readlines())
        for base, word in bases_words:
            words_base_forms[word].append(base)
    return dict(words_base_forms)


def sample_two_grams(sample_probability):
    two_grams = []
    for line in open("2grams.txt", "r"):
        if np.random.rand() > sample_probability:
            continue
        two_grams.append(tuple(line.strip().split(' ')[1:3]))
    return two_grams
    

def sample_three_grams(sample_probability):
    three_grams = []
    for line in open("3grams.txt", "r"):
        if np.random.rand() > sample_probability:
            continue
        three_grams.append(tuple(line.strip().split(' ')[1:4]))
    return three_grams

# %%
class DisjointSet(object):
    def __init__(self, vertex):
        self.vertex = vertex
        self.parent = self
        self.rank = 0
        
    @staticmethod
    def find_representative(disjoint_set):
        if disjoint_set != disjoint_set.parent:
            disjoint_set.parent = DisjointSet.find_representative(disjoint_set.parent)
        return disjoint_set.parent
    
    @staticmethod
    def union_sets(disjoint_set1, disjoint_set2):
        repr1 = DisjointSet.find_representative(disjoint_set1)
        repr2 = DisjointSet.find_representative(disjoint_set2)
        if repr1.rank > repr2.rank:
            repr2.parent = repr1
        elif repr1.rank < repr2.rank:
            repr1.parent = repr2
        else:
            repr1.parent = repr2
            repr2.rank += 1

# %%
def union_base_forms(joined_base_forms, base_forms_disjoint_sets):
    for base_forms in joined_base_forms:
        disjoint_set1 = base_forms_disjoint_sets[base_forms[0]]
        for i in range(1, len(base_forms)):
            disjoint_set2 = base_forms_disjoint_sets[base_forms[i]]
            DisjointSet.union_sets(disjoint_set1, disjoint_set2)    


def reverse_base_forms_disjoint_sets(base_forms_disjoint_sets):
    disjoint_sets_base_forms = defaultdict(lambda: [])
    for base_form, disjoint_set in base_forms_disjoint_sets.items():
        representative = DisjointSet.find_representative(disjoint_set)
        disjoint_sets_base_forms[representative].append(base_form)    
    return dict(disjoint_sets_base_forms)


def create_base_forms_superbase_forms(words_base_forms):
    all_base_forms = set(itertools.chain(*words_base_forms.values()))    
    base_forms_disjoint_sets = {x: DisjointSet(x) for x in all_base_forms}
    union_base_forms(words_base_forms.values(), base_forms_disjoint_sets)
    disjoint_sets_base_forms = reverse_base_forms_disjoint_sets(base_forms_disjoint_sets)
    base_forms_superbase_forms = {}
    for joined_base_forms in disjoint_sets_base_forms.values():
        superbase_form = '|'.join(sorted(joined_base_forms))
        for joined_base_form in joined_base_forms:
            base_forms_superbase_forms[joined_base_form] = superbase_form
    return base_forms_superbase_forms

# %%
def analyze_base_forms_in_common_superbase_form(words_base_forms, word_ngrams):
    for word_index in range(len(word_ngrams[0])):
        for i in range(len(word_ngrams)):
            for j in range(i + 1, len(word_ngrams)):
                word_ngram1 = word_ngrams[i]
                word_ngram2 = word_ngrams[j]
                word1_base_forms = words_base_forms[word_ngram1[word_index]]
                word2_base_forms = words_base_forms[word_ngram2[word_index]]
                if len(set(word1_base_forms).intersection(set(word2_base_forms))) == 0:
                    joined_ngram1 = ' '.join(word_ngram1)
                    joined_ngram2 = ' '.join(word_ngram2)
                    print(f"Found ngrams: '{joined_ngram1}' & '{joined_ngram2}'")
    

def analyze_base_forms_in_superbase_forms(word_ngrams):
    words_base_forms = read_words_base_forms()
    base_forms_superbase_forms = create_base_forms_superbase_forms(words_base_forms)    
    superbase_forms_word_ngrams = defaultdict(lambda: [])
    for word_ngram in word_ngrams:
        if any([x not in words_base_forms for x in word_ngram]):
            continue
        ngram_superbase_forms = list(map(
            lambda x: base_forms_superbase_forms[words_base_forms[x][0]],
            word_ngram
        ))
        ngram_superbase_form = ' '.join(ngram_superbase_forms)
        superbase_forms_word_ngrams[ngram_superbase_form].append(word_ngram)
    for word_ngrams in superbase_forms_word_ngrams.values():
        analyze_base_forms_in_common_superbase_form(words_base_forms, word_ngrams)

# %%
two_grams = sample_two_grams(sample_probability=0.01)
three_grams = sample_three_grams(sample_probability=0.01)

# %%
analyze_base_forms_in_superbase_forms(two_grams + three_grams)
# Out:
# Found ngrams: 'ojciec ich' & 'ocean jego'
# Found ngrams: 'działa w' & 'dzielony we'
# Found ngrams: 'ile to' & 'ile ty'
# Found ngrams: 'jak ona' & 'jakimi ich'
# Found ngrams: 'jak one' & 'jakimi ich'
# Found ngrams: 'mieszczą się' & 'ma sobie'
# Found ngrams: 'mieszczą się' & 'mieni się'
# Found ngrams: 'mieszczą się' & 'mieliście się'
# Found ngrams: 'mieszczą się' & 'miałeś sobie'
# Found ngrams: 'ma sobie' & 'mieni się'
# Found ngrams: 'ma sobie' & 'mieszczeniu się'
# Found ngrams: 'ma sobie' & 'mieściłaś się'
# Found ngrams: 'mieni się' & 'mieliście się'
# Found ngrams: 'mieni się' & 'miałeś sobie'
# Found ngrams: 'mieni się' & 'mieszczeniu się'
# Found ngrams: 'mieni się' & 'mieściłaś się'
# Found ngrams: 'mieliście się' & 'mieszczeniu się'
# Found ngrams: 'mieliście się' & 'mieściłaś się'
# Found ngrams: 'miałeś sobie' & 'mieszczeniu się'
# Found ngrams: 'miałeś sobie' & 'mieściłaś się'
# Found ngrams: 'których jest' & 'któremu bardzo'
# Found ngrams: 'któremu bardzo' & 'którą będziesz'
# Found ngrams: 'któremu bardzo' & 'którym będąc'
# Found ngrams: 'w moją' & 'wiekowych miałem'
# Found ngrams: 'w mai' & 'wiekowych miałem'
# Found ngrams: 'wiekowych miałem' & 'wieków masz'
# Found ngrams: 'wiekowych miałem' & 'wieków mieści'
# Found ngrams: 'wiekowych miałem' & 'w maj'
# Found ngrams: 'w moją' & 'w mai'
# Found ngrams: 'w moją' & 'wiekowych miałem'
# Found ngrams: 'w moją' & 'wieków masz'
# Found ngrams: 'w moją' & 'wieków mieści'
# Found ngrams: 'w moją' & 'w maj'
# Found ngrams: 'w mai' & 'wiekowych miałem'
# Found ngrams: 'w mai' & 'wieków masz'
# Found ngrams: 'w mai' & 'wieków mieści'
# Found ngrams: 'wiekowych miałem' & 'wieków mieści'
# Found ngrams: 'wiekowych miałem' & 'w maj'
# Found ngrams: 'wieków masz' & 'wieków mieści'
# Found ngrams: 'wieków masz' & 'w maj'
# Found ngrams: 'wieków mieści' & 'w maj'
# Found ngrams: 'z gry' & 'ze grany'
# Found ngrams: 'miałem w' & 'me w'
# Found ngrams: 'miałem w' & 'mieścić w'
# Found ngrams: 'me w' & 'mieścić w'
# Found ngrams: 'będą także' & 'barach także'
# Found ngrams: 'ze jest' & 'z barem'
# Found ngrams: 'im dłużej' & 'ich długiej'
# Found ngrams: 'im dłużej' & 'je długie'
# Found ngrams: 'im dłużej' & 'nich długimi'
# Found ngrams: 'im dłużej' & 'oni długie'
# Found ngrams: 'tych działań' & 'tym działających'
# Found ngrams: 'najczęściej jest' & 'częstsza była'
# Found ngrams: 'najczęściej byli' & 'częstsza była'
# Found ngrams: 'najczęściej jest' & 'często bardziej'
# Found ngrams: 'często bardziej' & 'najczęściej byli'
# Found ngrams: 'często bardziej' & 'często będąc'
# Found ngrams: 'często bardziej' & 'częstsza była'
# Found ngrams: 'miejsce jest' & 'miejscu bardzo'
# Found ngrams: 'sejmu z' & 'sejmowy z'
# Found ngrams: 'bardzo cię' & 'byłem to'
# Found ngrams: 'bardzo cię' & 'być ciebie'
# Found ngrams: 'bardzo cię' & 'byłem to'
# Found ngrams: 'byłem to' & 'być ciebie'
# Found ngrams: 'był ich' & 'będzie jedzenia'
# Found ngrams: 'jestem mu' & 'będzie jedzenia'
# Found ngrams: 'jest nimi' & 'będzie jedzenia'
# Found ngrams: 'będącym ich' & 'będzie jedzenia'
# Found ngrams: 'będzie jedzenia' & 'będziecie im'
# Found ngrams: 'ze sprzętem' & 'ze sprzętowym'
# Found ngrams: 'się wielki' & 'się dusiliśmy'
# Found ngrams: 'początku był' & 'początkowo będące'
# Found ngrams: 'początek będziemy' & 'początkowo będące'
# Found ngrams: 'początkowo będące' & 'początki był'
# Found ngrams: 'tych swoich' & 'ciebie swe'
# Found ngrams: 'tych swoich' & 'tobą swoimi'
# Found ngrams: 'wypadek w' & 'wypadkowych w'
# Found ngrams: 'wypadek w' & 'wypadkowy w'
# Found ngrams: 'nich miał' & 'jej mój'
# Found ngrams: 'nich miał' & 'je moja'
# Found ngrams: 'nich miał' & 'im moja'
# Found ngrams: 'nich miał' & 'nie mieściłyby'
# Found ngrams: 'nich miał' & 'go miotłą'
# Found ngrams: 'jej mój' & 'ona miano'
# Found ngrams: 'jej mój' & 'nią miało'
# Found ngrams: 'jej mój' & 'jemu miało'
# Found ngrams: 'jej mój' & 'nie mieściłyby'
# Found ngrams: 'jej mój' & 'go miotłą'
# Found ngrams: 'je moja' & 'ona miano'
# Found ngrams: 'je moja' & 'nią miało'
# Found ngrams: 'je moja' & 'jemu miało'
# Found ngrams: 'je moja' & 'nie mieściłyby'
# Found ngrams: 'je moja' & 'go miotłą'
# Found ngrams: 'im moja' & 'ona miano'
# Found ngrams: 'im moja' & 'nią miało'
# Found ngrams: 'im moja' & 'jemu miało'
# Found ngrams: 'im moja' & 'nie mieściłyby'
# Found ngrams: 'im moja' & 'go miotłą'
# Found ngrams: 'ona miano' & 'nie mieściłyby'
# Found ngrams: 'ona miano' & 'go miotłą'
# Found ngrams: 'nią miało' & 'nie mieściłyby'
# Found ngrams: 'nią miało' & 'go miotłą'
# Found ngrams: 'jemu miało' & 'nie mieściłyby'
# Found ngrams: 'jemu miało' & 'go miotłą'
# Found ngrams: 'nie mieściłyby' & 'go miotłą'
# Found ngrams: 'społeczeństwo jest' & 'społeczeństwach bardziej'
# Found ngrams: 'społeczeństwach bardziej' & 'społeczeństwo być'
# Found ngrams: 'będzie działał' & 'są działaniom'
# Found ngrams: 'byłoby działać' & 'są działaniom'
# Found ngrams: 'których wcześniej' & 'którego wcześniejszy'
# Found ngrams: 'ma trafić' & 'maju trafi'
# Found ngrams: 'mniej czasu' & 'małego czasu'
# Found ngrams: 'tymi wszystkimi' & 'ciebie wszystko'
# Found ngrams: 'tymi wszystkimi' & 'ciebie wszystko'
# Found ngrams: 'jest silnie' & 'było silny'
# Found ngrams: 'była silnie' & 'było silny'
# Found ngrams: 'było silny' & 'był najsilniej'
# Found ngrams: 'był najsilniej' & 'byliśmy silni'
# Found ngrams: 'mam dwie' & 'moje dwie'
# Found ngrams: 'na umieszczenie' & 'na umówione'
# Found ngrams: 'twoja mama' & 'twoja moja'
# Found ngrams: 'twej mamy' & 'twoja moja'
# Found ngrams: 'i wiedzę' & 'i niewiedzące'
# Found ngrams: 'ma mu' & 'maj nie'
# Found ngrams: 'ma mu' & 'mamię go'
# Found ngrams: 'mam ją' & 'maj nie'
# Found ngrams: 'masz nie' & 'maj nie'
# Found ngrams: 'masz nie' & 'mamię go'
# Found ngrams: 'maj nie' & 'mam jedzenie'
# Found ngrams: 'maj nie' & 'mam one'
# Found ngrams: 'maj nie' & 'mamię go'
# Found ngrams: 'ma mu' & 'mam jedzenie'
# Found ngrams: 'mam ją' & 'mam jedzenie'
# Found ngrams: 'masz nie' & 'mam jedzenie'
# Found ngrams: 'maj nie' & 'mam jedzenie'
# Found ngrams: 'mam jedzenie' & 'mam one'
# Found ngrams: 'mam jedzenie' & 'mamię go'
# Found ngrams: 'podatku i' & 'podatkowym i'
# Found ngrams: 'firma miała' & 'firmy mamiły'
# Found ngrams: 'roku podatkowego' & 'rok podatek'
# Found ngrams: 'jest wysoka' & 'byli wyżej'
# Found ngrams: 'być wyższy' & 'byli wyżej'
# Found ngrams: 'byli wyżej' & 'bądź wyższego'
# Found ngrams: 'byli wyżej' & 'było wysokim'
# Found ngrams: 'byli wyżej' & 'był wyższą'
# Found ngrams: 'nie śniło' & 'im snu'
# Found ngrams: 'sąd ma' & 'sądowego miał'
# Found ngrams: 'sądowego miał' & 'sąd mają'
# Found ngrams: 'być kimś' & 'bardzo ktoś'
# Found ngrams: 'przecie nie' & 'przejął je'
# Found ngrams: 'przecie nie' & 'przejęły jej'
# Found ngrams: 'dłużej na' & 'dłuższy na'
# Found ngrams: 'mama miała' & 'miałem mieć'
# Found ngrams: 'mama miała' & 'miała moją'
# Found ngrams: 'mama miała' & 'ma macie'
# Found ngrams: 'mama miała' & 'moje mieściły'
# Found ngrams: 'miałem mieć' & 'moje mieściły'
# Found ngrams: 'miała moją' & 'moje mieściły'
# Found ngrams: 'mama miała' & 'miała moją'
# Found ngrams: 'mama miała' & 'moje mieściły'
# Found ngrams: 'miałem mieć' & 'miała moją'
# Found ngrams: 'miałem mieć' & 'moje mieściły'
# Found ngrams: 'miała moją' & 'ma macie'
# Found ngrams: 'miała moją' & 'moje mieściły'
# Found ngrams: 'ma macie' & 'moje mieściły'
# Found ngrams: 'jej był' & 'imiesłowy są'
# Found ngrams: 'nimi bardzo' & 'imiesłowy są'
# Found ngrams: 'mu był' & 'imiesłowy są'
# Found ngrams: 'nim byłam' & 'imiesłowy są'
# Found ngrams: 'nich bar' & 'imiesłowy są'
# Found ngrams: 'nie byty' & 'imiesłowy są'
# Found ngrams: 'imiesłowy są' & 'jego byłaby'
# Found ngrams: 'im bardzo' & 'jej był'
# Found ngrams: 'im bardzo' & 'mu był'
# Found ngrams: 'im bardzo' & 'nim byłam'
# Found ngrams: 'im bardzo' & 'nich bar'
# Found ngrams: 'im bardzo' & 'nie byty'
# Found ngrams: 'im bardzo' & 'imiesłowy są'
# Found ngrams: 'im bardzo' & 'jego byłaby'
# Found ngrams: 'jej był' & 'nimi bardzo'
# Found ngrams: 'jej był' & 'nich bar'
# Found ngrams: 'jej był' & 'nie byty'
# Found ngrams: 'nimi bardzo' & 'mu był'
# Found ngrams: 'nimi bardzo' & 'nim byłam'
# Found ngrams: 'nimi bardzo' & 'nich bar'
# Found ngrams: 'nimi bardzo' & 'nie byty'
# Found ngrams: 'nimi bardzo' & 'imiesłowy są'
# Found ngrams: 'nimi bardzo' & 'jego byłaby'
# Found ngrams: 'mu był' & 'nich bar'
# Found ngrams: 'mu był' & 'nie byty'
# Found ngrams: 'nim byłam' & 'nich bar'
# Found ngrams: 'nim byłam' & 'nie byty'
# Found ngrams: 'nich bar' & 'nie byty'
# Found ngrams: 'nich bar' & 'imiesłowy są'
# Found ngrams: 'nich bar' & 'jego byłaby'
# Found ngrams: 'nie byty' & 'imiesłowy są'
# Found ngrams: 'nie byty' & 'jego byłaby'
# Found ngrams: 'regionie jest' & 'regionach byłego'
# Found ngrams: 'regionach byłego' & 'regionu byłby'
# Found ngrams: 'będą i' & 'byłym i'
# Found ngrams: 'będą i' & 'bara i'
# Found ngrams: 'byłym i' & 'bara i'
# Found ngrams: 'byłym i' & 'byłyście i'
# Found ngrams: 'bara i' & 'byłyście i'
# Found ngrams: 'los w' & 'losowych w'
# Found ngrams: 'temu udało' & 'cię udane'
# Found ngrams: 'cię udane' & 'tego udany'
# Found ngrams: 'dwie panie' & 'dwa pkt'
# Found ngrams: 'maja z' & 'maile z'
# Found ngrams: 'maja z' & 'mieściły ze'
# Found ngrams: 'maja z' & 'mojego ze'
# Found ngrams: 'maile z' & 'mieściły ze'
# Found ngrams: 'maile z' & 'mojego ze'
# Found ngrams: 'mieściły ze' & 'mojego ze'
# Found ngrams: 'i gier' & 'i grający'
# Found ngrams: 'i gier' & 'i godzinie'
# Found ngrams: 'i gier' & 'i graniem'
# Found ngrams: 'i grający' & 'i godzinie'
# Found ngrams: 'i godzinie' & 'i graniem'
# Found ngrams: 'umówiła się' & 'umiałam się'
# Found ngrams: 'bardzo ładny' & 'być ładnym'
# Found ngrams: 'bardzo ładny' & 'był ładnym'
# Found ngrams: 'bardzo ładny' & 'byliście ładną'
# Found ngrams: 'nich zbyt' & 'ją zbyć'
# Found ngrams: 'jego wieku' & 'jedzonego w'
# Found ngrams: 'programy te' & 'programowe tej'
# Found ngrams: 'prac sejmowych' & 'pracom sejmu'
# Found ngrams: 'mnie źle' & 'ja gorąco'
# Found ngrams: 'moja najlepsza' & 'masz dobrych'
# Found ngrams: 'moi dobrzy' & 'masz dobrych'
# Found ngrams: 'reprezentować będą' & 'reprezentowały bardzo'
# Found ngrams: 'wszyscy ją' & 'wszom nie'
# Found ngrams: 'jak panowie' & 'jako pkt'
# Found ngrams: 'jej dać' & 'im dat'
# Found ngrams: 'jemu da' & 'im dat'
# Found ngrams: 'musiał on' & 'muchy nie'
# Found ngrams: 'muchy nie' & 'musimy nie'
# Found ngrams: 'muchy nie' & 'musiałam jeść'
# Found ngrams: 'muchy nie' & 'musieliście ją'
# Found ngrams: 'musiał on' & 'musiałam jeść'
# Found ngrams: 'muchy nie' & 'musiałam jeść'
# Found ngrams: 'musimy nie' & 'musiałam jeść'
# Found ngrams: 'musiałam jeść' & 'musieliście ją'
# Found ngrams: 'były wcześniej' & 'jesteśmy wczesnym'
# Found ngrams: 'bądź wcześniej' & 'jesteśmy wczesnym'
# Found ngrams: 'z pocztą' & 'z pocztowych'
# Found ngrams: 'ma przyjść' & 'maja przyszłam'
# Found ngrams: 'złożony i' & 'złożach i'
# Found ngrams: 'ja stałem' & 'mnie stanowiło'
# Found ngrams: 'ja stałem' & 'ja stanął'
# Found ngrams: 'mnie stanie' & 'mnie stanowiło'
# Found ngrams: 'mnie stanowiło' & 'ja staliśmy'
# Found ngrams: 'mnie stanowiło' & 'ja stała'
# Found ngrams: 'mnie stanowiło' & 'ja stanął'
# Found ngrams: 'ja staliśmy' & 'ja stanął'
# Found ngrams: 'ja stała' & 'ja stanął'
# Found ngrams: 'której mieści' & 'których miała'
# Found ngrams: 'której mieści' & 'którą mój'
# Found ngrams: 'której mieści' & 'którą miano'
# Found ngrams: 'której mieści' & 'którą miałabym'
# Found ngrams: 'których miała' & 'którą mój'
# Found ngrams: 'którą mój' & 'którą miano'
# Found ngrams: 'którą mój' & 'którą miałabym'
# Found ngrams: 'go wszyscy' & 'jemu wszystko'
# Found ngrams: 'regulaminową i' & 'regulaminach i'
# Found ngrams: 'i budżet' & 'i budżetowo'
# Found ngrams: 'odpowiednio wcześnie' & 'odpowiednio wczesnego'
# Found ngrams: 'stoją już' & 'stanowił już'
# Found ngrams: 'stoją już' & 'stanowiło już'
# Found ngrams: 'o równym' & 'o równaniu'
# Found ngrams: 'grał pan' & 'godziny panu'
# Found ngrams: 'gra punkt' & 'godziny panu'
# Found ngrams: 'godziny panu' & 'grająca piętro'
# Found ngrams: 'godziny panu' & 'grający pana'
# Found ngrams: 'grał pan' & 'gra punkt'
# Found ngrams: 'grał pan' & 'grająca piętro'
# Found ngrams: 'gra punkt' & 'godziny panu'
# Found ngrams: 'gra punkt' & 'grająca piętro'
# Found ngrams: 'gra punkt' & 'grający pana'
# Found ngrams: 'godziny panu' & 'grająca piętro'
# Found ngrams: 'grająca piętro' & 'grający pana'
# Found ngrams: 'jesteśmy narodem' & 'będących narodową'
# Found ngrams: 'miał przez' & 'mail przez'
# Found ngrams: 'jak mogli' & 'jakich może'
# Found ngrams: 'jak mogli' & 'jakiej mogłem'
# Found ngrams: 'nie rosną' & 'nim rosę'
# Found ngrams: 'im rosły' & 'nim rosę'
# Found ngrams: 'nie rosnącą' & 'nim rosę'
# Found ngrams: 'stałe lub' & 'stanąć lub'
# Found ngrams: 'stałe lub' & 'stoisz lub'
# Found ngrams: 'stanąć lub' & 'stoisz lub'
# Found ngrams: 'byt w' & 'niebędącego w'
# Found ngrams: 'z osiedli' & 'z osiadłym'
# Found ngrams: 'z osiedli' & 'z oso'
# Found ngrams: 'z osiedli' & 'z osiadłą'
# Found ngrams: 'z osiadłym' & 'z oso'
# Found ngrams: 'z oso' & 'z osiadłą'
# Found ngrams: 'jak zacznie' & 'jakie zaczęło'
# Found ngrams: 'bardzo popularnym' & 'bądź popularnym'
# Found ngrams: 'stanie je' & 'stanowią ją'
# Found ngrams: 'stanie je' & 'stanowiącego ich'
# Found ngrams: 'stanowią ją' & 'stanęli im'
# Found ngrams: 'stanęli im' & 'stanowiącego ich'
# Found ngrams: 'nie mniejsza' & 'jej najmniej'
# Found ngrams: 'niego mały' & 'jej najmniej'
# Found ngrams: 'jej najmniej' & 'nim najmniejszej'
# Found ngrams: 'jej najmniej' & 'ona najmniejszą'
# Found ngrams: 'powiatowy i' & 'powieściami i'
# Found ngrams: 'strony było' & 'sekund są'
# Found ngrams: 'strony było' & 'sekundy była'
# Found ngrams: 'stronach jest' & 'sekund są'
# Found ngrams: 'stronach jest' & 'sekundy była'
# Found ngrams: 'sekund są' & 'strona był'
# Found ngrams: 'sekund są' & 'stronie jesteś'
# Found ngrams: 'sekundy była' & 'strona był'
# Found ngrams: 'sekundy była' & 'stronie jesteś'
# Found ngrams: 'i osiągnięć' & 'i osiągniętą'
# Found ngrams: 'i osiągnięć' & 'i osiągnięta'
# Found ngrams: 'samorządu jest' & 'samorządowego będzie'
# Found ngrams: 'samorządy są' & 'samorządowego będzie'
# Found ngrams: 'dom będzie' & 'domowych są'
# Found ngrams: 'piękny jest' & 'pięknie byłoby'
# Found ngrams: 'piękny jest' & 'pięknie bardzo'
# Found ngrams: 'piękny jest' & 'pięknie bardzo'
# Found ngrams: 'pięknie byłoby' & 'pięknie bardzo'
# Found ngrams: 'pięknie bardzo' & 'piękno będące'
# Found ngrams: 'roku mam' & 'roku mieściła'
# Found ngrams: 'roku mam' & 'lat mym'
# Found ngrams: 'lat masz' & 'roku mieściła'
# Found ngrams: 'lat masz' & 'lat mym'
# Found ngrams: 'roku mieściła' & 'lat mym'
# Found ngrams: 'zainteresowani naszym' & 'zainteresowaniom nasze'
# Found ngrams: 'one nadal' & 'jedli nadal'
# Found ngrams: 'nie śpię' & 'im spaleniem'
# Found ngrams: 'nimi śpicie' & 'im spaleniem'
# Found ngrams: 'im spaleniem' & 'nich spałem'
# Found ngrams: 'im spaleniem' & 'nim spałaś'
# Found ngrams: 'w dużą' & 'wiekach wielkiej'
# Found ngrams: 'obu jego' & 'obu jadłam'
# Found ngrams: 'wszyscy bądź' & 'wszystko będącej'
# Found ngrams: 'wszystkimi bardzo' & 'wszystko będącej'
# Found ngrams: 'wszystkim była' & 'wszystkimi bardzo'
# Found ngrams: 'wszyscy bądź' & 'wszystkimi bardzo'
# Found ngrams: 'wszyscy bądź' & 'wszystkim byłą'
# Found ngrams: 'wszystkimi bardzo' & 'wszystkim byłą'
# Found ngrams: 'wszystkimi bardzo' & 'wszystko będącej'
# Found ngrams: 'wszystkim byłą' & 'wszystko będącej'
# Found ngrams: 'strzela w' & 'strzelone w'
# Found ngrams: 'strzelali w' & 'strzelone w'
# Found ngrams: 'to standard' & 'ta standardowa'
# Found ngrams: 'to standard' & 'tych standardowych'
# Found ngrams: 'końca był' & 'końcowy będący'
# Found ngrams: 'końcu być' & 'końcowy będący'
# Found ngrams: 'życie są' & 'żyję bieżącą'
# Found ngrams: 'żyjący byli' & 'żyję bieżącą'
# Found ngrams: 'jakie ci' & 'jak tym'
# Found ngrams: 'stworzenia takiego' & 'stworzone tak'
# Found ngrams: 'czasem od' & 'czasowe od'
# Found ngrams: 'było poza' & 'bardzo poza'
# Found ngrams: 'ją lepiej' & 'jeść dobrze'
# Found ngrams: 'ten zbiór' & 'te zbiorowe'
# Found ngrams: 'miałam być' & 'maja są'
# Found ngrams: 'miałam być' & 'maja bądź'
# Found ngrams: 'miałam być' & 'maju byłem'
# Found ngrams: 'miałam być' & 'mat był'
# Found ngrams: 'miałam być' & 'mielony było'
# Found ngrams: 'miałam być' & 'mój bądź'
# Found ngrams: 'miał bardziej' & 'maja są'
# Found ngrams: 'miał bardziej' & 'maja bądź'
# Found ngrams: 'miał bardziej' & 'maju byłem'
# Found ngrams: 'miał bardziej' & 'mat był'
# Found ngrams: 'miał bardziej' & 'mielony było'
# Found ngrams: 'miał bardziej' & 'mój bądź'
# Found ngrams: 'mający bardzo' & 'maja są'
# Found ngrams: 'mający bardzo' & 'maja bądź'
# Found ngrams: 'mający bardzo' & 'maju byłem'
# Found ngrams: 'mający bardzo' & 'mat był'
# Found ngrams: 'mający bardzo' & 'mielony było'
# Found ngrams: 'mający bardzo' & 'mój bądź'
# Found ngrams: 'maja są' & 'mat był'
# Found ngrams: 'maja są' & 'mieliśmy bądź'
# Found ngrams: 'maja są' & 'mielony było'
# Found ngrams: 'maja są' & 'mój bądź'
# Found ngrams: 'maja bądź' & 'mat był'
# Found ngrams: 'maja bądź' & 'mieliśmy bądź'
# Found ngrams: 'maja bądź' & 'mielony było'
# Found ngrams: 'maja bądź' & 'mój bądź'
# Found ngrams: 'maju byłem' & 'mat był'
# Found ngrams: 'maju byłem' & 'mieliśmy bądź'
# Found ngrams: 'maju byłem' & 'mielony było'
# Found ngrams: 'maju byłem' & 'mój bądź'
# Found ngrams: 'mat był' & 'mieliśmy bądź'
# Found ngrams: 'mat był' & 'mielony było'
# Found ngrams: 'mat był' & 'mój bądź'
# Found ngrams: 'mieliśmy bądź' & 'mielony było'
# Found ngrams: 'mieliśmy bądź' & 'mój bądź'
# Found ngrams: 'mielony było' & 'mój bądź'
# Found ngrams: 'miałam być' & 'miał bardziej'
# Found ngrams: 'miałam być' & 'mający bardzo'
# Found ngrams: 'miał bardziej' & 'maja są'
# Found ngrams: 'miał bardziej' & 'maja bądź'
# Found ngrams: 'miał bardziej' & 'maju byłem'
# Found ngrams: 'miał bardziej' & 'mat był'
# Found ngrams: 'miał bardziej' & 'mieliśmy bądź'
# Found ngrams: 'miał bardziej' & 'mielony było'
# Found ngrams: 'miał bardziej' & 'mój bądź'
# Found ngrams: 'mający bardzo' & 'maja są'
# Found ngrams: 'mający bardzo' & 'maja bądź'
# Found ngrams: 'mający bardzo' & 'maju byłem'
# Found ngrams: 'mający bardzo' & 'mat był'
# Found ngrams: 'mający bardzo' & 'mieliśmy bądź'
# Found ngrams: 'mający bardzo' & 'mielony było'
# Found ngrams: 'mający bardzo' & 'mój bądź'
# Found ngrams: 'listów nie' & 'liść ich'
# Found ngrams: 'listu go' & 'liść ich'
# Found ngrams: 'dane były' & 'dama bardzo'
# Found ngrams: 'dane były' & 'dama bardzo'
# Found ngrams: 'i ukryte' & 'i ukryciach'
# Found ngrams: 'jestem szefem' & 'bardziej szefem'
# Found ngrams: 'jestem szefem' & 'byłych szefach'
# Found ngrams: 'bardziej szefem' & 'byłych szefach'
# Found ngrams: 'teraz powiem' & 'teraz powiatowym'
# Found ngrams: 'teraz powiedziałem' & 'teraz powiatowym'
# Found ngrams: 'trzecia nie' & 'tarły ją'
# Found ngrams: 'trzecią nie' & 'tarły ją'
# Found ngrams: 'również moje' & 'również mieści'
# Found ngrams: 'również obecny' & 'również obywatelem'
# Found ngrams: 'również obecny' & 'również obywatelowi'
# Found ngrams: 'również obecnym' & 'również obywatelem'
# Found ngrams: 'również obecnym' & 'również obywatelowi'
# Found ngrams: 'koła jest' & 'kolega będący'
# Found ngrams: 'możemy grać' & 'mógł gromić'
# Found ngrams: 'wszystkich spotkań' & 'wszystkich spotka'
# Found ngrams: 'ograniczonych praw' & 'ograniczeniom praw'
# Found ngrams: 'ograniczeniom praw' & 'ograniczyły prawa'
# Found ngrams: 'projekcje filmów' & 'projekcje filmowych'
# Found ngrams: 'widząc ich' & 'widzeń nie'
# Found ngrams: 'widzeń nie' & 'widziało jej'
# Found ngrams: 'zawodowego na' & 'zawodami na'
# Found ngrams: 'moich ludzi' & 'mieć człowieka'
# Found ngrams: 'moich ludzi' & 'majowe lud'
# Found ngrams: 'mieć człowieka' & 'majowe lud'
# Found ngrams: 'moich ludzi' & 'majowe lud'
# Found ngrams: 'mieć człowieka' & 'majowe lud'
# Found ngrams: 'bije i' & 'bitami i'
# Found ngrams: 'było pani' & 'były punkty'
# Found ngrams: 'było pani' & 'będę panów'
# Found ngrams: 'było pani' & 'było punkty'
# Found ngrams: 'były punkty' & 'będę panów'
# Found ngrams: 'będę panów' & 'było punkty'
# Found ngrams: 'miał długie' & 'miały dług'
# Found ngrams: 'działań może' & 'dzielonych może'
# Found ngrams: 'mam wielkie' & 'masz najwięcej'
# Found ngrams: 'mam wielkie' & 'miały dużej'
# Found ngrams: 'mające największe' & 'masz najwięcej'
# Found ngrams: 'masz najwięcej' & 'miały dużej'
# Found ngrams: 'mojemu ojcu' & 'miano o'
# Found ngrams: 'mojemu ojcu' & 'miałeś ojciec'
# Found ngrams: 'mojemu ojcu' & 'mieszczą o'
# Found ngrams: 'miano o' & 'mieszczą o'
# Found ngrams: 'miałeś ojciec' & 'mieszczą o'
# Found ngrams: 'bardziej efektywny' & 'są efektywna'
# Found ngrams: 'czuję jak' & 'czułą jak'
# Found ngrams: 'dokonał on' & 'dokonaniami ich'
# Found ngrams: 'uwagę panu' & 'uwagę paniom'
# Found ngrams: 'i trwałą' & 'i trwająca'
# Found ngrams: 'i trwałą' & 'i trwamy'
# Found ngrams: 'to mowa' & 'ciebie mówiącego'
# Found ngrams: 'to mowa' & 'ci mówili'
# Found ngrams: 'to mowa' & 'ciebie mówiącego'
# Found ngrams: 'było mówione' & 'bardziej mówili'
# Found ngrams: 'powiatów nie' & 'powiedziałam nie'
# Found ngrams: 'powiatów nie' & 'powiedzcie je'
# Found ngrams: 'powiatów nie' & 'powiedzieć on'
# Found ngrams: 'powiatów nie' & 'powiodą go'
# Found ngrams: 'powiedziałam nie' & 'powiodą go'
# Found ngrams: 'powiedzcie je' & 'powiodą go'
# Found ngrams: 'powiedzieć on' & 'powiodą go'
# Found ngrams: 'myślę tak' & 'myślami taką'
# Found ngrams: 'myślami taką' & 'myślącymi tak'
# Found ngrams: 'pani mu' & 'punkcie jego'
# Found ngrams: 'pani mu' & 'punktowego nie'
# Found ngrams: 'punkcie jego' & 'punktowego nie'
# Found ngrams: 'staliby tak' & 'stałe takiej'
# Found ngrams: 'staniu tak' & 'stałe takiej'
# Found ngrams: 'stałe takiej' & 'staną takie'
# Found ngrams: 'stała tak' & 'stałe takiej'
# Found ngrams: 'stała tak' & 'staną takie'
# Found ngrams: 'staliby tak' & 'stałe takiej'
# Found ngrams: 'staliby tak' & 'staną takie'
# Found ngrams: 'staniu tak' & 'stałe takiej'
# Found ngrams: 'staniu tak' & 'staną takie'
# Found ngrams: 'bo stan' & 'bo staliśmy'
# Found ngrams: 'bo stan' & 'bo stanowiła'
# Found ngrams: 'bo staliśmy' & 'bo stanowiła'
# Found ngrams: 'jak kochać' & 'jakie kochał'
# Found ngrams: 'nie musza' & 'on musieliśmy'
# Found ngrams: 'tym taka' & 'tobą takich'
# Found ngrams: 'jest wymiar' & 'bardzo wymiary'
# Found ngrams: 'nie postawili' & 'nią postawy'
# Found ngrams: 'są jednostkami' & 'byłą jednostką'
# Found ngrams: 'gdzie mieściły' & 'gdzie mieć'
# Found ngrams: 'autobusu do' & 'autobusowy do'
# Found ngrams: 'jest starszym' & 'barze stary'
# Found ngrams: 'jest starszym' & 'bardzo staremu'
# Found ngrams: 'barze stary' & 'będzie najstarszy'
# Found ngrams: 'barze stary' & 'bardzo staremu'
# Found ngrams: 'barze stary' & 'byłyśmy starymi'
# Found ngrams: 'będzie najstarszy' & 'bardzo staremu'
# Found ngrams: 'bardzo staremu' & 'byłyśmy starymi'
# Found ngrams: 'powiedzieć ze' & 'powiedź z'
# Found ngrams: 'róża i' & 'różowych i'
# Found ngrams: 'uczyć nie' & 'uczniach nie'
# Found ngrams: 'uczniach nie' & 'uczyłam ich'
# Found ngrams: 'uczniach nie' & 'uczono jego'
# Found ngrams: 'uczniach nie' & 'uczyć jeść'
# Found ngrams: 'uczyć nie' & 'uczyć jeść'
# Found ngrams: 'uczniach nie' & 'uczyć jeść'
# Found ngrams: 'uczyłam ich' & 'uczyć jeść'
# Found ngrams: 'uczono jego' & 'uczyć jeść'
# Found ngrams: 'ulicy parkowej' & 'ulicą park'
# Found ngrams: 'byłaś z' & 'barze z'
# Found ngrams: 'wzniesione w' & 'wzniosłe w'
# Found ngrams: 'zadaniem ma' & 'zadaszenie ma'
# Found ngrams: 'zadania miał' & 'zadaszenie ma'
# Found ngrams: 'zadaszenie ma' & 'zadań mam'
# Found ngrams: 'żądania są' & 'żądając bardzo'
# Found ngrams: 'ją jeden' & 'nie jednam'
# Found ngrams: 'nich jednych' & 'nie jednam'
# Found ngrams: 'podstawę tego' & 'podstawić ci'
# Found ngrams: 'istnieją bardzo' & 'istniejących będą'
# Found ngrams: 'mam jednego' & 'mieścił jeden'
# Found ngrams: 'mają jedni' & 'mieścił jeden'
# Found ngrams: 'paszy i' & 'pasmo i'
# Found ngrams: 'postanowił sprzedać' & 'postanowiły sprzedawać'
# Found ngrams: 'takich pracowników' & 'tak pracownicy'
# Found ngrams: 'wypełnionych kart' & 'wypełnianie kart'
# Found ngrams: 'wypełnianie kart' & 'wypełniły karty'
# Found ngrams: 'jak byłoby' & 'jakich będzie'
# Found ngrams: 'jak byłoby' & 'jakie będę'
# Found ngrams: 'jak byłoby' & 'jacy być'
# Found ngrams: 'jak byłoby' & 'jakimi było'
# Found ngrams: 'jakich będzie' & 'jak byłego'
# Found ngrams: 'jakie będę' & 'jak byłego'
# Found ngrams: 'jacy być' & 'jak byłego'
# Found ngrams: 'jakimi było' & 'jak byłego'
# Found ngrams: 'jak byłoby' & 'jaką bardzo'
# Found ngrams: 'jak byłoby' & 'jak byłego'
# Found ngrams: 'jakich będzie' & 'jaką bardzo'
# Found ngrams: 'jakich będzie' & 'jak byłego'
# Found ngrams: 'jakie będę' & 'jaką bardzo'
# Found ngrams: 'jakie będę' & 'jak byłego'
# Found ngrams: 'jaką bardzo' & 'jacy być'
# Found ngrams: 'jaką bardzo' & 'jakimi było'
# Found ngrams: 'jaką bardzo' & 'jak byłego'
# Found ngrams: 'jacy być' & 'jak byłego'
# Found ngrams: 'terenie byłych' & 'terenie będą'
# Found ngrams: 'być największym' & 'będziemy więcej'
# Found ngrams: 'będziemy więcej' & 'być największe'
# Found ngrams: 'będziemy więcej' & 'byłbym wielkim'
# Found ngrams: 'jestem dużo' & 'byłbym wielkim'
# Found ngrams: 'takimi nie' & 'tak jecie'
# Found ngrams: 'takiemu on' & 'tak jecie'
# Found ngrams: 'takimi nie' & 'tak jecie'
# Found ngrams: 'takiemu on' & 'tak jecie'
# Found ngrams: 'ich czy' & 'jadł czy'
# Found ngrams: 'im czy' & 'jadł czy'
# Found ngrams: 'lejek i' & 'lejców i'
# Found ngrams: 'mu pewnie' & 'on pewnymi'
# Found ngrams: 'stacja będzie' & 'stołecznej były'
# Found ngrams: 'też wyjątkowo' & 'też wyjątki'
# Found ngrams: 'wyjaśnienia te' & 'wyjaśniać te'
# Found ngrams: 'wyjaśnienia te' & 'wyjaśniając to'
# Found ngrams: 'wyjaśnienia te' & 'wyjaśniająca te'
# Found ngrams: 'wyjaśnię ci' & 'wyjaśniać te'
# Found ngrams: 'wyjaśnię ci' & 'wyjaśniając to'
# Found ngrams: 'wyjaśnię ci' & 'wyjaśniająca te'
# Found ngrams: 'wyjaśniać te' & 'wyjaśnimy tego'
# Found ngrams: 'wyjaśniając to' & 'wyjaśnimy tego'
# Found ngrams: 'wyjaśniająca te' & 'wyjaśnimy tego'
# Found ngrams: 'nie popełniali' & 'nim popełnić'
# Found ngrams: 'nie popełniano' & 'nim popełnić'
# Found ngrams: 'jej popełniać' & 'nim popełnić'
# Found ngrams: 'są przerażeni' & 'bardzo przerażony'
# Found ngrams: 'była właściwa' & 'bardziej właściwą'
# Found ngrams: 'jest najwłaściwszą' & 'bardziej właściwą'
# Found ngrams: 'bardziej właściwą' & 'byłaby właściwym'
# Found ngrams: 'kilka mieszkań' & 'kilku mieszkających'
# Found ngrams: 'moja myśl' & 'miałem myśli'
# Found ngrams: 'moja myśl' & 'maja myślę'
# Found ngrams: 'miałem myśli' & 'maja myślę'
# Found ngrams: 'popularna była' & 'popularnym barze'
# Found ngrams: 'anioły z' & 'aniela z'
# Found ngrams: 'dusza jego' & 'dużym nie'
# Found ngrams: 'dusza jego' & 'większe im'
# Found ngrams: 'dusza jego' & 'wielkiemu jej'
# Found ngrams: 'dużym nie' & 'wielkiemu jej'
# Found ngrams: 'części tekstu' & 'częścią tekstowego'
# Found ngrams: 'dusiła się' & 'większym się'
# Found ngrams: 'jako pojęcie' & 'jakich pojęć'
# Found ngrams: 'podłączane do' & 'podłączonej do'
# Found ngrams: 'podłączane do' & 'niepodłączoną do'
# Found ngrams: 'zwycięzca będzie' & 'zwycięzcą bardzo'
# Found ngrams: 'krwawe i' & 'krwawiąc i'
# Found ngrams: 'roku prowadzone' & 'latem prowadziliśmy'
# Found ngrams: 'są poszukiwani' & 'bardzo poszukiwanymi'
# Found ngrams: 'się psa' & 'się psi'
# Found ngrams: 'się psem' & 'się psi'
# Found ngrams: 'się psi' & 'siebie psy'
# Found ngrams: 'się psi' & 'sobie psami'
# Found ngrams: 'będą jeździli' & 'b jeździ'
# Found ngrams: 'jedno moje' & 'jedno miałbym'
# Found ngrams: 'oznacza mniej' & 'oznacza małe'
# Found ngrams: 'robi dużo' & 'robić wielki'
# Found ngrams: 'robi dużo' & 'robili wielcy'
# Found ngrams: 'wcześniej prezes' & 'wcześniejszych prezesów'
# Found ngrams: 'bardziej były' & 'bieżącego są'
# Found ngrams: 'bardziej były' & 'bieżąco był'
# Found ngrams: 'bardziej były' & 'byliśmy będzie'
# Found ngrams: 'bieżącego są' & 'byliśmy będzie'
# Found ngrams: 'bieżąco był' & 'byliśmy będzie'
# Found ngrams: 'połączeniach z' & 'połączeni ze'
# Found ngrams: 'prowadzenia domu' & 'prowadzić domowe'
# Found ngrams: 'prowadzić domowe' & 'prowadziła domy'
# Found ngrams: 'rady mają' & 'radzi mamie'
# Found ngrams: 'tym niebezpiecznym' & 'ciebie niebezpieczną'
# Found ngrams: 'nie ureguluje' & 'one uregulowań'
# Found ngrams: 'nie uregulowali' & 'one uregulowań'
# Found ngrams: 'one podstawą' & 'nie podstawił'
# Found ngrams: 'nie podstawił' & 'oni podstawy'
# Found ngrams: 'się rozwiązań' & 'się rozwiąże'
# Found ngrams: 'wyżej notowanych' & 'wyższe notowania'
# Found ngrams: 'była skupiona' & 'bardzo skupiony'
# Found ngrams: 'była skupiona' & 'bardzo skupili'
# Found ngrams: 'część mienia' & 'często macie'
# Found ngrams: 'często macie' & 'częścią ma'
# Found ngrams: 'często macie' & 'częścią miała'
# Found ngrams: 'dziać z' & 'niedzieloną z'
# Found ngrams: 'dziać z' & 'działamy ze'
# Found ngrams: 'niedzieloną z' & 'działamy ze'
# Found ngrams: 'i umarłych' & 'i umrzemy'
# Found ngrams: 'ją wodą' & 'jego wodzów'
# Found ngrams: 'niej wodę' & 'jego wodzów'
# Found ngrams: 'jego wodzów' & 'go woda'
# Found ngrams: 'jego wodzów' & 'ją wodę'
# Found ngrams: 'maciek w' & 'maćkowej w'
# Found ngrams: 'takiego też' & 'tak tęgo'
# Found ngrams: 'takiego też' & 'tak tęgo'
# Found ngrams: 'tego brać' & 'ten brat'
# Found ngrams: 'ten brat' & 'ten brany'
# Found ngrams: 'ten brat' & 'tę biorę'
# Found ngrams: 'zawodów został' & 'zawodowy został'
# Found ngrams: 'za lepszego' & 'za dobrem'
# Found ngrams: 'znał tych' & 'zna cię'
# Found ngrams: 'a powierzchnią' & 'a powiatowym'
# Found ngrams: 'gier to' & 'gramatyka ta'
# Found ngrams: 'jakich materiałów' & 'jako materiały'
# Found ngrams: 'krajowe firmy' & 'kraju firmy'
# Found ngrams: 'wzrostu wpływów' & 'wzrosły wpływy'
# Found ngrams: 'że stanowiła' & 'że stałbyś'
# Found ngrams: 'bardzo przyjazne' & 'barów przyjaznych'
# Found ngrams: 'moje intencje' & 'miał intencje'
# Found ngrams: 'mojej intencji' & 'miał intencje'
# Found ngrams: 'stoi jakaś' & 'stanowią jakieś'
# Found ngrams: 'stoi jakaś' & 'stanowiliśmy jakąś'
# Found ngrams: 'wymaga dobrego' & 'wymaganiom dobra'
# Found ngrams: 'i wymyślać' & 'i wymyśliły'
# Found ngrams: 'jest rosnący' & 'będziemy rościć'
# Found ngrams: 'będzie rosnąca' & 'będziemy rościć'
# Found ngrams: 'kolorów z' & 'kolorowa z'
# Found ngrams: 'minął bez' & 'minucie bez'
# Found ngrams: 'tonu w' & 'tomach w'
# Found ngrams: 'były oczy' & 'będący około'
# Found ngrams: 'debata sejmowa' & 'debat sejmu'
# Found ngrams: 'drugie bardzo' & 'druga być'
# Found ngrams: 'drugie bardzo' & 'drugi jesteśmy'
# Found ngrams: 'dzieci miało' & 'dziecka mojego'
# Found ngrams: 'lub film' & 'lubisz filmowego'
# Found ngrams: 'lub filmach' & 'lubisz filmowego'
# Found ngrams: 'starcie stanęli' & 'startowym stał'
# Found ngrams: 'starcie stanęli' & 'startowym stał'
# Found ngrams: 'tę skalę' & 'tych skałach'
# Found ngrams: 'to przyjął' & 'ciebie przyjąć'
# Found ngrams: 'tę przyjąłem' & 'ciebie przyjąć'
# Found ngrams: 'tych bloków' & 'to blokowa'
# Found ngrams: 'wola do' & 'wołana do'
# Found ngrams: 'we dzieli' & 'wieku działające'
# Found ngrams: 'w działających' & 'we dzieli'
# Found ngrams: 'we dzieli' & 'wieku działające'
# Found ngrams: 'będącym częścią' & 'jestem najczęściej'
# Found ngrams: 'byłym mistrzem' & 'będzie mistrza'
# Found ngrams: 'był sen' & 'bardzo senator'
# Found ngrams: 'bardzo senator' & 'byłby senator'
# Found ngrams: 'granicy powiatu' & 'granic powiatowych'
# Found ngrams: 'i doskonałych' & 'i doskonalony'
# Found ngrams: 'kiedyś stały' & 'kiedyś stanęłam'
# Found ngrams: 'nie płaciłem' & 'jedzenie płacili'
# Found ngrams: 'nie płaćcie' & 'jedzenie płacili'
# Found ngrams: 'rozdzielić te' & 'rozdzielać to'
# Found ngrams: 'rozdzielić te' & 'rozdziela tej'
# Found ngrams: 'rozdzielone to' & 'rozdzielać to'
# Found ngrams: 'rozdzielone to' & 'rozdziela tej'
# Found ngrams: 'także stanu' & 'także stojąc'
# Found ngrams: 'ten powiedział' & 'to powiaty'
# Found ngrams: 'to powiaty' & 'to powiedzieliby'
# Found ngrams: 'tym prosimy' & 'cię prosiła'
# Found ngrams: 'to prosiłabym' & 'cię prosiła'
# Found ngrams: 'dawno miałem' & 'dawną moją'
# Found ngrams: 'dawno pan' & 'dawniejszej pani'
# Found ngrams: 'gospodarczej będzie' & 'gospodarek jest'
# Found ngrams: 'gospodarczej będzie' & 'gospodarkach jest'
# Found ngrams: 'gospodarczej będzie' & 'gospodarek będzie'
# Found ngrams: 'gospodarcza są' & 'gospodarek jest'
# Found ngrams: 'gospodarcza są' & 'gospodarkach jest'
# Found ngrams: 'gospodarcza są' & 'gospodarek będzie'
# Found ngrams: 'jakie doświadczenia' & 'jak niedoświadczony'
# Found ngrams: 'napisać tak' & 'napisaliśmy takie'
# Found ngrams: 'nią pan' & 'nim pań'
# Found ngrams: 'oddać tę' & 'oddalenia tego'
# Found ngrams: 'oddalenia tego' & 'oddaliśmy te'
# Found ngrams: 'oddalenia tego' & 'oddasz tę'
# Found ngrams: 'trzy ofiary' & 'trzecia ofiar'
# Found ngrams: 'trzy ofiary' & 'trzecią ofiarę'
# Found ngrams: 'zajęć to' & 'zajmie te'
# Found ngrams: 'zajęć to' & 'zająłby tę'
# Found ngrams: 'arabskim i' & 'ara i'
# Found ngrams: 'dania mu' & 'dal nich'
# Found ngrams: 'dałoby im' & 'dal nich'
# Found ngrams: 'dacie mu' & 'dal nich'
# Found ngrams: 'danie jego' & 'dal nich'
# Found ngrams: 'i gwaru' & 'i gwara'
# Found ngrams: 'jej obliczenia' & 'ona obliczana'
# Found ngrams: 'polska stanęła' & 'polskiej stanowiącego'
# Found ngrams: 'stałe jest' & 'stoją bardzo'
# Found ngrams: 'stałe jest' & 'stojących bądź'
# Found ngrams: 'stałe jest' & 'stanowego są'
# Found ngrams: 'stoją bardzo' & 'stanowego są'
# Found ngrams: 'stojących bądź' & 'stanowego są'
# Found ngrams: 'stali byłby' & 'stanowego są'
# Found ngrams: 'stałe jest' & 'stoją bardzo'
# Found ngrams: 'stoją bardzo' & 'stojących bądź'
# Found ngrams: 'stoją bardzo' & 'stali byłby'
# Found ngrams: 'stoją bardzo' & 'stanowego są'
# Found ngrams: 'bardzo specyficzną' & 'było specyficzną'
# Found ngrams: 'często długo' & 'część długiej'
# Found ngrams: 'góra będzie' & 'górze bardziej'
# Found ngrams: 'góra będzie' & 'górami bardzo'
# Found ngrams: 'górze bardziej' & 'góry byłam'
# Found ngrams: 'góry byłam' & 'górami bardzo'
# Found ngrams: 'nie przeżyłabym' & 'jej przeżyciom'
# Found ngrams: 'interesów tej' & 'interes ty'
# Found ngrams: 'i kierunkiem' & 'i kierunkowy'
# Found ngrams: 'jest trafić' & 'barem trafiłem'
# Found ngrams: 'na najdłuższym' & 'na długu'
# Found ngrams: 'południu po' & 'południowa po'
# Found ngrams: 'przeziębień i' & 'przeziębi i'
# Found ngrams: 'wziął tę' & 'wziąłbym cię'
# Found ngrams: 'wziąłbym cię' & 'weźmie tych'
# Found ngrams: 'wziąłbym cię' & 'wzięto ten'
# Found ngrams: 'cień jej' & 'cienko nie'
# Found ngrams: 'których sprzedawano' & 'którym sprzedano'
# Found ngrams: 'których sprzedawano' & 'którą sprzedać'
# Found ngrams: 'którym sprzedano' & 'który sprzedawały'
# Found ngrams: 'którą sprzedać' & 'który sprzedawały'
# Found ngrams: 'mieli przygotować' & 'mojego nieprzygotowania'
# Found ngrams: 'mieć przygotowany' & 'mojego nieprzygotowania'
# Found ngrams: 'miała przygotowanie' & 'mojego nieprzygotowania'
# Found ngrams: 'muszę dużo' & 'musiało wielkie'
# Found ngrams: 'nie określili' & 'jego określeniach'
# Found ngrams: 'nie określili' & 'on określeniami'
# Found ngrams: 'osiągnięć ucznia' & 'osiągnięciach uczy'
# Found ngrams: 'wszystkich sprzedanych' & 'wszystko sprzedamy'
# Found ngrams: 'zabytek i' & 'zabytkowy i'
# Found ngrams: 'zajęć było' & 'zajęci będą'
# Found ngrams: 'zajęcie byłym' & 'zajęci będą'
# Found ngrams: 'a mojemu' & 'a mamę'
# Found ngrams: 'a zdrowy' & 'a zdrowiem'
# Found ngrams: 'całych zawodach' & 'całym zawodowym'
# Found ngrams: 'jest najtrudniej' & 'bardziej trudnego'
# Found ngrams: 'były najtrudniejsze' & 'bardziej trudnego'
# Found ngrams: 'bardziej trudnego' & 'będące najtrudniejszą'
# Found ngrams: 'jest najtrudniej' & 'były najtrudniejsze'
# Found ngrams: 'jest najtrudniej' & 'bardziej trudnego'
# Found ngrams: 'jest najtrudniej' & 'będące najtrudniejszą'
# Found ngrams: 'kościoła będzie' & 'kościołowi bardziej'
# Found ngrams: 'miał powierzchnię' & 'miał powiedział'
# Found ngrams: 'miesięcy mam' & 'miesiące mojego'
# Found ngrams: 'miesiące mojego' & 'miesiącach miałam'
# Found ngrams: 'oddano mu' & 'oddaliłyby ich'
# Found ngrams: 'strzelały do' & 'strzeliłeś do'
# Found ngrams: 'strzelacie do' & 'strzeliłeś do'
# Found ngrams: 'zawodowy ma' & 'zawodów mieścić'
# Found ngrams: 'zawodowe mające' & 'zawodów mieścić'
# Found ngrams: 'zawodowy ma' & 'zawodów mieścić'
# Found ngrams: 'zawodowe mające' & 'zawodów mieścić'
# Found ngrams: 'zobaczyłem tego' & 'zobaczyła ciebie'
# Found ngrams: 'żywiący się' & 'żywych się'
# Found ngrams: 'były programy' & 'bardzo program'
# Found ngrams: 'jest programów' & 'bardzo program'
# Found ngrams: 'finałowy o' & 'finałach o'
# Found ngrams: 'go silnie' & 'go silne'
# Found ngrams: 'go silnie' & 'jej silną'
# Found ngrams: 'go silnie' & 'on silny'
# Found ngrams: 'go silnie' & 'ona silnych'
# Found ngrams: 'go silnie' & 'niego silnego'
# Found ngrams: 'które powiat' & 'której powiedzieć'
# Found ngrams: 'które powiat' & 'któremu powieść'
# Found ngrams: 'które powiat' & 'którym powiedziane'
# Found ngrams: 'której powiedzieć' & 'któremu powieść'
# Found ngrams: 'któremu powieść' & 'którym powiedziane'
# Found ngrams: 'kwiecień był' & 'kwietniowa będzie'
# Found ngrams: 'mają mały' & 'mamą małego'
# Found ngrams: 'mają mały' & 'moja najmniejsza'
# Found ngrams: 'mieć najmniejszego' & 'mamą małego'
# Found ngrams: 'mieć najmniejszego' & 'moja najmniejsza'
# Found ngrams: 'mieć małe' & 'mamą małego'
# Found ngrams: 'mieć małe' & 'moja najmniejsza'
# Found ngrams: 'ma najmniejszy' & 'mamą małego'
# Found ngrams: 'mają najmniejszy' & 'mamą małego'
# Found ngrams: 'mają najmniejszy' & 'moja najmniejsza'
# Found ngrams: 'mamą małego' & 'miało mniejszy'
# Found ngrams: 'mamą małego' & 'mienie małej'
# Found ngrams: 'mamą małego' & 'moja najmniejsza'
# Found ngrams: 'mamy mniejszą' & 'moja najmniejsza'
# Found ngrams: 'miało mniejszy' & 'moja najmniejsza'
# Found ngrams: 'mienie małej' & 'moja najmniejsza'
# Found ngrams: 'mieszkają tylko' & 'mieszkań tylko'
# Found ngrams: 'moje liczne' & 'miałem licznych'
# Found ngrams: 'pełniła ona' & 'pełnym jej'
# Found ngrams: 'pełniła ona' & 'pełne jego'
# Found ngrams: 'pełnym jej' & 'pełnili ją'
# Found ngrams: 'pełnym jej' & 'pełniły ją'
# Found ngrams: 'pełnym jej' & 'pełniących nie'
# Found ngrams: 'pełne jego' & 'pełnili ją'
# Found ngrams: 'pełne jego' & 'pełniły ją'
# Found ngrams: 'pełne jego' & 'pełniących nie'
# Found ngrams: 'więcej zła' & 'wielką złą'
# Found ngrams: 'więcej zła' & 'największego zła'
# Found ngrams: 'wzrostu były' & 'wzrośnie bardzo'
# Found ngrams: 'wzrost bądź' & 'wzrośnie bardzo'
# Found ngrams: 'wzrostu były' & 'wzrośnie bardzo'
# Found ngrams: 'wzrost bądź' & 'wzrośnie bardzo'
# Found ngrams: 'zamieszkania są' & 'zamieszki były'
# Found ngrams: 'bardziej dojrzałych' & 'jestem dojrzałym'
# Found ngrams: 'celowego i' & 'celowaniu i'
# Found ngrams: 'grę przez' & 'grałam przez'
# Found ngrams: 'jest zdaje' & 'bardziej zdaje'
# Found ngrams: 'jest zdaje' & 'bardziej zdawał'
# Found ngrams: 'bardziej zdaje' & 'będzie zdawana'
# Found ngrams: 'bardziej zdawał' & 'będzie zdawana'
# Found ngrams: 'którym więcej' & 'której wielkie'
# Found ngrams: 'którym więcej' & 'który dusi'
# Found ngrams: 'którym więcej' & 'któremu duszę'
# Found ngrams: 'którym więcej' & 'których duszę'
# Found ngrams: 'której wielkie' & 'który dusi'
# Found ngrams: 'której wielkie' & 'któremu duszę'
# Found ngrams: 'której wielkie' & 'których duszę'
# Found ngrams: 'powiedział zmęczonym' & 'powiódł zmęczonym'
# Found ngrams: 'ratunkowa była' & 'ratunkiem był'
# Found ngrams: 'ruszymy w' & 'ruszałyśmy w'
# Found ngrams: 'ruszymy w' & 'rusztów w'
# Found ngrams: 'ruszysz w' & 'ruszałyśmy w'
# Found ngrams: 'ruszysz w' & 'rusztów w'
# Found ngrams: 'ruszałyśmy w' & 'rusztów w'
# Found ngrams: 'taką datę' & 'tacę dać'
# Found ngrams: 'tacę dać' & 'takich dat'
# Found ngrams: 'taką datę' & 'tacę dać'
# Found ngrams: 'tacę dać' & 'takich dat'
# Found ngrams: 'wielkiej determinacji' & 'dużo determinacji'
# Found ngrams: 'wyrzekł w' & 'wyrzeczeniach w'
# Found ngrams: 'będziemy czuli' & 'są czule'
# Found ngrams: 'jest najczulszą' & 'są czule'
# Found ngrams: 'gospodarczą prowadzoną' & 'gospodarkę prowadzoną'
# Found ngrams: 'gospodarczą prowadziłem' & 'gospodarkę prowadzoną'
# Found ngrams: 'i mucha' & 'i musiałyśmy'
# Found ngrams: 'jakaś więź' & 'jakiegoś więźnia'
# Found ngrams: 'jako zmiany' & 'jakimi zmianami'
# Found ngrams: 'oraz zarządy' & 'oraz zarządzić'
# Found ngrams: 'prawie miliona' & 'prawie milionowa'
# Found ngrams: 'tego bądź' & 'to bar'
# Found ngrams: 'to bar' & 'ci niebędący'
# Found ngrams: 'to bar' & 'tę bądź'
# Found ngrams: 'to nazwali' & 'cię nazwać'
# Found ngrams: 'wiedzą pana' & 'wiedziałaby pani'
# Found ngrams: 'w uczniu' & 'wiek uczeni'
# Found ngrams: 'zainteresowani takimi' & 'zainteresowania tak'
# Found ngrams: 'zdjęć będzie' & 'zdjęcia byłego'
# Found ngrams: 'zgromadzeniach i' & 'zgromadzona i'
# Found ngrams: 'było lżej' & 'było lekki'
# Found ngrams: 'był świętym' & 'były świętem'
# Found ngrams: 'były świętem' & 'był świętej'
# Found ngrams: 'czy rodzaju' & 'czy rodzinie'
# Found ngrams: 'czy wysokiej' & 'czy wysoce'
# Found ngrams: 'granice mojej' & 'granic miała'
# Found ngrams: 'i przejdę' & 'i przeszłym'
# Found ngrams: 'je szczegółowo' & 'nich szczegóły'
# Found ngrams: 'je szczegółowo' & 'niej szczegół'
# Found ngrams: 'mu szczegółowo' & 'nich szczegóły'
# Found ngrams: 'mu szczegółowo' & 'niej szczegół'
# Found ngrams: 'nich szczegóły' & 'jego szczegółowym'
# Found ngrams: 'jego szczegółowym' & 'niej szczegół'
# Found ngrams: 'już puste' & 'już puszczę'
# Found ngrams: 'mam serdeczną' & 'moi serdeczni'
# Found ngrams: 'odbudowie kraju' & 'odbudowy krajowej'
# Found ngrams: 'rządowy ustawy' & 'rzędem ustawione'
# Found ngrams: 'rządowy ustawy' & 'rzędem ustawione'
# Found ngrams: 'samochodem jak' & 'samochodowym jako'
# Found ngrams: 'samochodzie są' & 'samochodowej była'
# Found ngrams: 'tych przedstawień' & 'temu przedstawił'
# Found ngrams: 'dysponując tak' & 'dysponowali takimi'
# Found ngrams: 'go rząd' & 'jej rządowe'
# Found ngrams: 'jedzą ich' & 'oni nim'
# Found ngrams: 'jedzą ich' & 'niemu oni'
# Found ngrams: 'który uzna' & 'którego uznawał'
# Found ngrams: 'który uzna' & 'które uznajesz'
# Found ngrams: 'miałeś tak' & 'mieli takimi'
# Found ngrams: 'miałeś tak' & 'niemający takiego'
# Found ngrams: 'między uprawnieniami' & 'między uprawnionymi'
# Found ngrams: 'między uprawnieniami' & 'między uprawnione'
# Found ngrams: 'nie sprzedasz' & 'jej sprzedawać'
# Found ngrams: 'nie sprzedasz' & 'ich sprzedawanie'
# Found ngrams: 'jej sprzedawać' & 'ich sprzeda'
# Found ngrams: 'jej sprzedawać' & 'niej sprzedasz'
# Found ngrams: 'jej sprzedawać' & 'nim sprzedał'
# Found ngrams: 'ich sprzeda' & 'ich sprzedawanie'
# Found ngrams: 'ich sprzedawanie' & 'niej sprzedasz'
# Found ngrams: 'ich sprzedawanie' & 'nim sprzedał'
# Found ngrams: 'jemu najbliżej' & 'nimi bliższe'
# Found ngrams: 'przed czasami' & 'przed czasowym'
# Found ngrams: 'rekord oglądalności' & 'rekordową oglądalnością'
# Found ngrams: 'sama postawa' & 'samym postawiony'
# Found ngrams: 'sposób jestem' & 'sposobami bardziej'
# Found ngrams: 'sposobowi bycia' & 'sposobami bardziej'
# Found ngrams: 'stanowiły po' & 'stanęłam po'
# Found ngrams: 'także działają' & 'także działów'
# Found ngrams: 'także działają' & 'także działaniach'
# Found ngrams: 'także działają' & 'także dzielimy'
# Found ngrams: 'także działów' & 'także działaniach'
# Found ngrams: 'także działów' & 'także dzielimy'
# Found ngrams: 'także działów' & 'także działającej'
# Found ngrams: 'także działaniach' & 'także dzielimy'
# Found ngrams: 'także działaniach' & 'także działającej'
# Found ngrams: 'także dzielimy' & 'także działającej'
# Found ngrams: 'ty nosisz' & 'tego noszenia'
# Found ngrams: 'umiałem znaleźć' & 'um znajdzie'
# Found ngrams: 'umielibyśmy znaleźć' & 'um znajdzie'
# Found ngrams: 'wygranej jest' & 'wygrać bieżącą'
# Found ngrams: 'wygranej były' & 'wygrać bieżącą'
# Found ngrams: 'być czytelnie' & 'będzie czytelny'
# Found ngrams: 'było doskonalenie' & 'byłoby doskonałą'
# Found ngrams: 'był typowo' & 'byłeś typem'
# Found ngrams: 'był typowo' & 'jesteśmy typami'
# Found ngrams: 'ciągłe zagrożenie' & 'ciągle zagrożenie'
# Found ngrams: 'część krajowego' & 'częściej krajem'
# Found ngrams: 'części krajowej' & 'częściej krajem'
# Found ngrams: 'część krajowego' & 'częściej krajem'
# Found ngrams: 'części krajowej' & 'częściej krajem'
# Found ngrams: 'fundacji będzie' & 'fundacje bardziej'
# Found ngrams: 'fundacji były' & 'fundacje bardziej'
# Found ngrams: 'grę we' & 'grałaś w'
# Found ngrams: 'go czcimy' & 'jej czcią'
# Found ngrams: 'jej czcią' & 'nich czczonego'
# Found ngrams: 'jej czcią' & 'nie czczę'
# Found ngrams: 'jej czcią' & 'nie czczona'
# Found ngrams: 'może mieścić' & 'mogę masz'
# Found ngrams: 'może mieścić' & 'może mianem'
# Found ngrams: 'mogę masz' & 'może mianem'
# Found ngrams: 'najmniejszą w' & 'mniej wiekowi'
# Found ngrams: 'niej myślał' & 'ich myślach'
# Found ngrams: 'ich myślach' & 'im myślisz'
# Found ngrams: 'obywateli będą' & 'obecne bardzo'
# Found ngrams: 'obywateli będą' & 'obecne bardzo'
# Found ngrams: 'pościeli z' & 'posłania z'
# Found ngrams: 'rozpoznając ten' & 'rozpoznamy tej'
# Found ngrams: 'rozpoznamy tej' & 'rozpoznawał tego'
# Found ngrams: 'rynku staje' & 'rynkowego staje'
# Found ngrams: 'standardu nie' & 'standardowo jego'
# Found ngrams: 'umieścimy go' & 'umiejących go'
# Found ngrams: 'umieścimy go' & 'umówili go'
# Found ngrams: 'umiejących go' & 'umówili go'
# Found ngrams: 'uznana na' & 'uznając na'
# Found ngrams: 'uznawali to' & 'uznaliby cię'
# Found ngrams: 'uznawali to' & 'uznałam ci'
# Found ngrams: 'uznawał to' & 'uznaliby cię'
# Found ngrams: 'uznawał to' & 'uznałam ci'
# Found ngrams: 'uznawali to' & 'uznaliby cię'
# Found ngrams: 'uznawał to' & 'uznaliby cię'
# Found ngrams: 'wielkiej wyprawy' & 'dużą wyprawę'
# Found ngrams: 'zagrożony będzie' & 'zagrożeń będą'
# Found ngrams: 'zagrożony będzie' & 'zagrożeń bytu'
# Found ngrams: 'zagrożeń będą' & 'zagrożonym bardzo'
# Found ngrams: 'zagrożeń bytu' & 'zagrożonym bardzo'
# Found ngrams: 'zagrożeniem był' & 'zagrożeń bytu'
# Found ngrams: 'zagrożeniem był' & 'zagrożonym bardzo'
# Found ngrams: 'zagrożony będzie' & 'zagrożeń bytu'
# Found ngrams: 'zagrożony będzie' & 'zagrożonym bardzo'
# Found ngrams: 'zagrożeń będą' & 'zagrożeń bytu'
# Found ngrams: 'zagrożeń będą' & 'zagrożonym bardzo'
# Found ngrams: 'zagrożeń bytu' & 'zagrożonym bardzo'
# Found ngrams: 'bardzo suchej' & 'być sucho'
# Found ngrams: 'będzie przekazywane' & 'bieżąco przekazywane'
# Found ngrams: 'chorego są' & 'chorym bardziej'
# Found ngrams: 'filtr jest' & 'filtrowej były'
# Found ngrams: 'ich wspaniałe' & 'jedząc wspaniały'
# Found ngrams: 'jego wspaniałemu' & 'jedząc wspaniały'
# Found ngrams: 'nich wspaniali' & 'jedząc wspaniały'
# Found ngrams: 'kraju centrum' & 'krajowych centrów'
# Found ngrams: 'którą rano' & 'który ranił'
# Found ngrams: 'maja bowiem' & 'mój bowiem'
# Found ngrams: 'maja bowiem' & 'mieści bowiem'
# Found ngrams: 'mój bowiem' & 'mieści bowiem'
# Found ngrams: 'moich wierszach' & 'mam wiersz'
# Found ngrams: 'moim panem' & 'mieli pani'
# Found ngrams: 'moim panem' & 'ma pań'
# Found ngrams: 'moim panem' & 'mieli pani'
# Found ngrams: 'mysz jest' & 'mysiej była'
# Found ngrams: 'nawet głowę' & 'nawet głowić'
# Found ngrams: 'nawet głową' & 'nawet głowić'
# Found ngrams: 'on pojawił' & 'jadło pojawiła'
# Found ngrams: 'ich pojawiło' & 'jadło pojawiła'
# Found ngrams: 'powiedzieliśmy na' & 'powiatową na'
# Found ngrams: 'powiedzieliśmy na' & 'powiodła na'
# Found ngrams: 'powiatową na' & 'powiedzieliście na'
# Found ngrams: 'powiatową na' & 'powiodła na'
# Found ngrams: 'powiedzieliście na' & 'powiodła na'
# Found ngrams: 'poznałem tę' & 'poznajemy to'
# Found ngrams: 'poznałem tę' & 'poznawałeś tego'
# Found ngrams: 'poznajemy to' & 'poznali ta'
# Found ngrams: 'poznali ta' & 'poznawałeś tego'
# Found ngrams: 'silnie powiązana' & 'silnym powiązaniem'
# Found ngrams: 'stołowy jest' & 'stołowy bardzo'
# Found ngrams: 'stołowego jest' & 'stołowy bardzo'
# Found ngrams: 'sztywnym i' & 'sztywnieję i'
# Found ngrams: 'tą białą' & 'to bielone'
# Found ngrams: 'zastosowań i' & 'zastosowana i'
# Found ngrams: 'zgasnąć w' & 'zgasłemu w'
# Found ngrams: 'albo karę' & 'albo karaniu'
# Found ngrams: 'były godziny' & 'bieżących gier'
# Found ngrams: 'były godziny' & 'bieżącej godziny'
# Found ngrams: 'bieżących gier' & 'były grający'
# Found ngrams: 'bieżących gier' & 'będą grani'
# Found ngrams: 'bieżących gier' & 'będzie grami'
# Found ngrams: 'były grający' & 'bieżącej godziny'
# Found ngrams: 'będą grani' & 'bieżącej godziny'
# Found ngrams: 'będzie grami' & 'bieżącej godziny'
# Found ngrams: 'były godziny' & 'bieżących gier'
# Found ngrams: 'były godziny' & 'były grający'
# Found ngrams: 'były godziny' & 'będą grani'
# Found ngrams: 'były godziny' & 'będzie grami'
# Found ngrams: 'bieżących gier' & 'były grający'
# Found ngrams: 'bieżących gier' & 'będą grani'
# Found ngrams: 'bieżących gier' & 'bieżącej godziny'
# Found ngrams: 'były grający' & 'będzie grami'
# ...
# Found ngrams: 'jakim było głosowanie' & 'jak będę głosował'
# Found ngrams: 'jakim to świadczy' & 'jak te świadczenia'
# Found ngrams: 'ja byłem pytany' & 'mnie bardzo pytał'
# Found ngrams: 'ja ją uznaję' & 'mi jego uznanie'
# Found ngrams: 'ją bardziej i' & 'jej będzie i'
# Found ngrams: 'ją pnąca się' & 'jego pienią się'
# Found ngrams: 'ją wodą odniesienia' & 'jego wodzą odniosła'
# Found ngrams: 'jeden dzień mam' & 'jednego dnia mój'
# Found ngrams: 'jednego dnia miał' & 'jednego dnia mój'
# Found ngrams: 'jednocześnie starali się' & 'jednocześnie starzeje się'
# Found ngrams: 'jedzenie narzekać nie' & 'nie narzekają one'
# Found ngrams: 'jego coraz silniejszym' & 'nimi coraz silniej'
# Found ngrams: 'jej być bardziej' & 'nią jest jest'
# Found ngrams: 'jej się najgorszą' & 'mu się gorszące'
# Found ngrams: 'jej wydziale byłego' & 'jej wydział był'
# Found ngrams: 'jest jednak pół' & 'są jednak polem'
# Found ngrams: 'jest ono puszczone' & 'jest on pustym'
# Found ngrams: 'jeszcze myśleć to' & 'jeszcze myślę ty'
# Found ngrams: 'jeżeli one tego' & 'jeżeli oni ty'
# Found ngrams: 'je takim duży' & 'niej tak dużą'
# Found ngrams: 'je takim duży' & 'nie tak dużej'
# Found ngrams: 'językiem połączonym ze' & 'językowy połączony z'
# Found ngrams: 'już będę stanowił' & 'już będziemy stać'
# Found ngrams: 'już będę stanowił' & 'już być stanem'
# Found ngrams: 'już będziemy stać' & 'już być stanem'
# Found ngrams: 'już mama z' & 'już miałam z'
# Found ngrams: 'kilku zdaniach jakie' & 'kilku zdaniach jako'
# Found ngrams: 'koncertowych i kolejnych' & 'koncert i kolejne'
# Found ngrams: 'kontakty z fotografem' & 'kontakt z fotografiami'
# Found ngrams: 'krajem będzie tak' & 'kraju jest takie'
# Found ngrams: 'krajowe kojarzą się' & 'kraju kojarzyła się'
# Found ngrams: 'książkę pożyczyłem od' & 'książki pożyczane od'
# Found ngrams: 'kształtów i takiej' & 'kształtu i tak'
# Found ngrams: 'która rano się' & 'którzy ranią się'
# Found ngrams: 'która stanowi pierwszy' & 'którzy stoją pierwsi'
# Found ngrams: 'którą będziesz kochała' & 'których bardzo kocham'
# Found ngrams: 'którą dzielona jest' & 'które działanie jest'
# Found ngrams: 'której nie stanowią' & 'które mu stoi'
# Found ngrams: 'której się miotła' & 'które się mieści'
# Found ngrams: 'której się miotła' & 'którym se ma'
# Found ngrams: 'które się mieści' & 'którym se ma'
# Found ngrams: 'któremu nie byłem' & 'których oni bardzo'
# Found ngrams: 'które bardzo wysoko' & 'którzy są wysocy'
# Found ngrams: 'które bardzo z' & 'które będzie z'
# Found ngrams: 'które on brał' & 'którym jego brat'
# Found ngrams: 'które płaci bardzo' & 'którzy płacić będą'
# Found ngrams: 'które popełniamy w' & 'które popełnili w'
# Found ngrams: 'które uznawałam za' & 'których uznaliśmy za'
# Found ngrams: 'które wielkie nie' & 'który duszy nie'
# Found ngrams: 'których część mieści' & 'którym najczęściej mamy'
# Found ngrams: 'których część mieści' & 'którym najczęściej mamy'
# Found ngrams: 'których nie ustał' & 'który ją ustalił'
# Found ngrams: 'których przyjęcie takiej' & 'który przyjął tak'
# Found ngrams: 'lataniu na miotle' & 'lata na moje'
# Found ngrams: 'lat ty masz' & 'roku tych moich'
# Found ngrams: 'lat ty masz' & 'roku tych moich'
# Found ngrams: 'łokciem opieram się' & 'łokciowa opiera się'
# Found ngrams: 'macie i z' & 'mojej i z'
# Found ngrams: 'maja obawiać się' & 'mama obawiała się'
# Found ngrams: 'maja pojawiają się' & 'ma pojawiający się'
# Found ngrams: 'maja tylko w' & 'mełła tylko w'
# Found ngrams: 'mają mamę i' & 'miał matową i'
# Found ngrams: 'mają nie i' & 'mamiąc je i'
# Found ngrams: 'majowym posiedzeniu sejmu' & 'ma posiedzeń sejmu'
# Found ngrams: 'majowy mieściło się' & 'moje mieściły się'
# Found ngrams: 'maju przynajmniej w' & 'ma przynajmniej w'
# Found ngrams: 'małego dziecka będą' & 'małe dziecko bardzo'
# Found ngrams: 'mamy punktów i' & 'mojej pani i'
# Found ngrams: 'mamy punktów i' & 'mojej pani i'
# Found ngrams: 'mamy znajoma ma' & 'moich znajomych miała'
# Found ngrams: 'mamy znajoma miała' & 'moich znajomych miała'
# Found ngrams: 'marzeń w tym' & 'marzyły w tym'
# Found ngrams: 'matach ojcu i' & 'ma ojców i'
# Found ngrams: 'ma dotychczas takiego' & 'miał dotychczas tak'
# Found ngrams: 'ma tylko bardzo' & 'miałam tylko być'
# Found ngrams: 'ma woda i' & 'mielące wodę i'
# Found ngrams: 'miałem brata i' & 'mym braciom i'
# Found ngrams: 'mieć interesu w' & 'moje interesy w'
# Found ngrams: 'miesięcy temu byłej' & 'miesięcy temu jest'
# Found ngrams: 'mogłam jej tak' & 'może ją takie'
# Found ngrams: 'mogłyby stanowić nie' & 'może stać ich'
# Found ngrams: 'może być wcześniejsze' & 'może byli wcześniej'
# Found ngrams: 'może do sierpnia' & 'może do sierpniowych'
# Found ngrams: 'mówić o duszeniu' & 'mówiłem o dużej'
# Found ngrams: 'musiała o tej' & 'musimy o tobie'
# Found ngrams: 'mu moja zapasowa' & 'nie miały zapadniętych'
# Found ngrams: 'mu moja zapasowa' & 'nie mieli zapasowego'
# Found ngrams: 'mu moja zapasowa' & 'nie miały zapadniętych'
# Found ngrams: 'nie miały zapadniętych' & 'nie mieli zapasowego'
# Found ngrams: 'myślałeś nie było' & 'myślą oni bardzo'
# Found ngrams: 'nad rzeką troją' & 'nad rzeką trzech'
# Found ngrams: 'najszybciej przygotować projekt' & 'szybkiego przygotowania projektu'
# Found ngrams: 'najwięcej ma być' & 'wielki miał być'
# Found ngrams: 'najwięcej powiedzieć i' & 'największej powierzchni i'
# Found ngrams: 'najwięcej powiedzieć i' & 'największej powierzchni i'
# Found ngrams: 'narodom znajdującym się' & 'narodowy znajdował się'
# Found ngrams: 'naszego miasta pewna' & 'naszym mieście pewnie'
# Found ngrams: 'nawet bardzo w' & 'nawet bylibyśmy w'
# Found ngrams: 'na myśli wysokich' & 'na myśl wysoce'
# Found ngrams: 'na nowo byłaby' & 'na nowo byłej'
# Found ngrams: 'na piętrze duży' & 'na piętrze wielki'
# Found ngrams: 'na rysunku lub' & 'na rysy lub'
# Found ngrams: 'nią działania nie' & 'nią dzieje nie'
# Found ngrams: 'niby pani nie' & 'niby pan nie'
# Found ngrams: 'niego naprawdę bardzo' & 'ona naprawdę będzie'
# Found ngrams: 'niego podłączenia do' & 'nie podłącza do'
# Found ngrams: 'niestojących wysoko w' & 'stanąć najwyższa w'
# Found ngrams: 'nie była starszym' & 'nie był starającym'
# Found ngrams: 'nie był starającym' & 'nie jest stare'
# Found ngrams: 'nie dostrzegam pani' & 'nie dostrzega panu'
# Found ngrams: 'nie ludzi się' & 'nim lud się'
# Found ngrams: 'nie ma kompleksowego' & 'nie miał kompleksów'
# Found ngrams: 'nie powiedzie mu' & 'nie powiesz jej'
# Found ngrams: 'nie wprowadzaliśmy takiego' & 'nie wprowadzały tak'
# Found ngrams: 'nie zawsze dzielone' & 'oni zawsze działają'
# Found ngrams: 'obiektów to bardzo' & 'obiektów to była'
# Found ngrams: 'obowiązek być tylko' & 'obowiązkowe jest tylko'
# Found ngrams: 'odmówić poparcia tak' & 'odmówiły poparcia takiego'
# Found ngrams: 'od niego miałam' & 'od niego mój'
# Found ngrams: 'ognia bądź też' & 'ogniowej był też'
# Found ngrams: 'oraz jakiej pomocy' & 'oraz jako pomoc'
# Found ngrams: 'otrzymują z zakładu' & 'otrzymywali z zakładowej'
# Found ngrams: 'o które stałem' & 'o którym stanowią'
# Found ngrams: 'o podejrzanym w' & 'o podejrzeniach w'
# Found ngrams: 'o wszystkim musze' & 'o wszystko musisz'
# Found ngrams: 'pani kciuki za' & 'pan kciuki za'
# Found ngrams: 'pani mu dać' & 'panom nie dała'
# Found ngrams: 'pani zrobić taką' & 'pan zrobi taką'
# Found ngrams: 'patrzeć na stojący' & 'patrzymy na stan'
# Found ngrams: 'patrze z bliska' & 'patrzę z bliska'
# Found ngrams: 'pewniejsze poruszanie się' & 'pewniej poruszał się'
# Found ngrams: 'pewnie na majowych' & 'pewno na moim'
# Found ngrams: 'pewnie na majowych' & 'pewno na moim'
# Found ngrams: 'początki nie mają' & 'początkowy nie ma'
# Found ngrams: 'poczcie e-maila z' & 'poczty e-mailowej z'
# Found ngrams: 'pocztą w formie' & 'pocztowych w formie'
# Found ngrams: 'połączenia z krajem' & 'połączeniu z krajową'
# Found ngrams: 'poprawić jakość zarządzania' & 'poprawy jakości zarządzania'
# Found ngrams: 'poręczanie kredytów dla' & 'poręczyły kredyty dla'
# Found ngrams: 'poszedłem za tobą' & 'pójścia za tym'
# Found ngrams: 'potwierdzenie to miało' & 'potwierdziło to moje'
# Found ngrams: 'powiatu to nie' & 'powiedziały to jej'
# Found ngrams: 'powiedzmy i to' & 'powierzchnią i tą'
# Found ngrams: 'powinna dawać więcej' & 'powinno dawać większy'
# Found ngrams: 'poznaje siebie na' & 'poznałam się na'
# Found ngrams: 'pozostawić tej ustawy' & 'pozostawić to ustawienie'
# Found ngrams: 'późna nie była' & 'później nie jesteś'
# Found ngrams: 'prace tych ludzi' & 'pracy tego ludu'
# Found ngrams: 'pracowała w przemysłowej' & 'pracują w przemyśle'
# Found ngrams: 'prawa chroniącego dobrego' & 'prawem chronionych dóbr'
# Found ngrams: 'prawej ręce panią' & 'prawej ręki pana'
# Found ngrams: 'przecie od nich' & 'przejąwszy od niego'
# Found ngrams: 'przedstawiła pani przewodnicząca' & 'przedstawi pan przewodniczący'
# Found ngrams: 'przez rok poznał' & 'przez rok poznawałem'
# Found ngrams: 'przywiązywać wielkiej wagi' & 'przywiązywał dużej wagi'
# Found ngrams: 'rachunek będzie dowodem' & 'rachunkowych są dowody'
# Found ngrams: 'raczej jej w' & 'raczył ich w'
# Found ngrams: 'realizacji programu stały' & 'realizacji programu stanowią'
# Found ngrams: 'rodzaju staje się' & 'rodzinami stawiły się'
# Found ngrams: 'rodzaju staje się' & 'rodzinami stawiły się'
# Found ngrams: 'rodzinę stać na' & 'rodzinom stanąć na'
# Found ngrams: 'rozpoznając apelacje pozwanych' & 'rozpoznania apelacji pozwanych'
# Found ngrams: 'rozpoznał swoją prawdziwą' & 'rozpoznawali swoje prawdziwe'
# Found ngrams: 'rozumienie i znajomość' & 'rozum i znajomość'
# Found ngrams: 'rynkach stają się' & 'rynkowych stają się'
# Found ngrams: 'samochodowy wpisze do' & 'samochód wpisany do'
# Found ngrams: 'sądem byłoby niezwykle' & 'sądowym był niezwykle'
# Found ngrams: 'sejmowej nie wyrażałem' & 'sejmu nie wyraża'
# Found ngrams: 'sekunda zaczęła się' & 'strona zacznie się'
# Found ngrams: 'siadając na dużych' & 'siadamy na wielkim'
# Found ngrams: 'siedząc z panią' & 'siedzimy z panem'
# Found ngrams: 'się na ostrej' & 'się na ostrzach'
# Found ngrams: 'się przyznajesz do' & 'się przyznało do'
# Found ngrams: 'siłą w jego' & 'sił w jedzeniu'
# Found ngrams: 'spodziewały się takiego' & 'spodziewa się tak'
# Found ngrams: 'sprawa to największa' & 'sprawiłoby ci największą'
# Found ngrams: 'sprawie powinien był' & 'sprawy powinien bardziej'
# Found ngrams: 'sprzyjające rozwojowi gospodarki' & 'sprzyjał rozwojowi gospodarczemu'
# Found ngrams: 'stale zatrudniony na' & 'stanu zatrudnionych na'
# Found ngrams: 'stało w kącie' & 'stanęła w kącie'
# Found ngrams: 'stał w zupełnej' & 'stanach w zupełnej'
# Found ngrams: 'stanach w zupełnej' & 'stojących w zupełnym'
# Found ngrams: 'stanąć gotowi do' & 'stoją gotowi do'
# Found ngrams: 'stanęła praca w' & 'stanowi prac w'
# Found ngrams: 'stanęła tyłem do' & 'stania tyłem do'
# Found ngrams: 'stronie jest najpiękniej' & 'stronie jest piękny'
# Found ngrams: 'strzelając bramki z' & 'strzelona bramka z'
# Found ngrams: 'szybciej dotarli na' & 'szybszego dotarcia na'
# Found ngrams: 'śmierci to moim' & 'śmierć ta miała'
# Found ngrams: 'święcona jest lepsza' & 'święto będzie dobrą'
# Found ngrams: 'świętami nie może' & 'święty nie mogliśmy'
# Found ngrams: 'takiego miałem na' & 'tak miały na'
# Found ngrams: 'tak będziesz stał' & 'tak była stale'
# Found ngrams: 'tak naprawdę wola' & 'tak naprawdę wolałabym'
# Found ngrams: 'ta jest złudna' & 'to bardzo złudna'
# Found ngrams: 'ta miała dużo' & 'ty masz większą'
# Found ngrams: 'to macie większą' & 'ty masz większą'
# Found ngrams: 'to mieć wielkiego' & 'ty masz większą'
# Found ngrams: 'ta miała dużo' & 'to mieć wielkiego'
# Found ngrams: 'techniką są często' & 'technikum jest najczęściej'
# Found ngrams: 'tego taka dziwna' & 'tobą tak dziwnie'
# Found ngrams: 'tego taka dziwna' & 'tobą tak dziwnie'
# Found ngrams: 'tego uczyć w' & 'tę ucztę w'
# Found ngrams: 'tego uznawać za' & 'to uznałam za'
# Found ngrams: 'tego z mniej' & 'tym z mniejszą'
# Found ngrams: 'temu powodem duszącego' & 'to powodem dużego'
# Found ngrams: 'temu traktowałaś mnie' & 'ty traktowałeś mnie'
# Found ngrams: 'ten przedstawi pan' & 'to przedstawić pani'
# Found ngrams: 'też jest pana' & 'też są punkty'
# Found ngrams: 'te ich balowe' & 'to nie bałem'
# Found ngrams: 'te strony pani' & 'tę stronę pana'
# Found ngrams: 'tę starą babę' & 'to starsze babcie'
# Found ngrams: 'tolerancja i pokój' & 'tolerancją i pokojową'
# Found ngrams: 'to byłoby działaniem' & 'tym bardziej dzielić'
# Found ngrams: 'to byłoby działaniem' & 'tym bardziej dzielić'
# Found ngrams: 'to działanie będące' & 'tych dziejów będzie'
# Found ngrams: 'to się próbowało' & 'ty sobie próbujesz'
# Found ngrams: 'to uczucie stać' & 'to uczucie stanąć'
# Found ngrams: 'to zrobię na' & 'ty zrobiłabyś na'
# Found ngrams: 'tych czasach miał' & 'tych czasów mój'
# Found ngrams: 'tych głowach się' & 'tym głowił się'
# Found ngrams: 'tygodniach byłem tak' & 'tygodniu były takie'
# Found ngrams: 'tylko o działaniu' & 'tylko o dzielenie'
# Found ngrams: 'tym się martw' & 'ty się martwisz'
# Found ngrams: 'ubezpieczeń powołują się' & 'ubezpieczonych powołuje się'
# Found ngrams: 'ubranymi w te' & 'ubrań w tym'
# Found ngrams: 'uczniów w jego' & 'uczyli w jego'
# Found ngrams: 'umieszczony byłby z' & 'umówiona jestem z'
# Found ngrams: 'umowie bardzo jej' & 'umowy są nie'
# Found ngrams: 'uprzedzała pani o' & 'uprzedzam panów o'
# Found ngrams: 'urodzisz i będziesz' & 'urodziwa i bardzo'
# Found ngrams: 'urodzisz i będziesz' & 'urodziwa i bardzo'
# Found ngrams: 'uznać za po' & 'uznajemy za po'
# Found ngrams: 'uznać za przełom' & 'uznanego za przełomowego'
# Found ngrams: 'u nas rzadszym' & 'u nas rzadziej'
# Found ngrams: 'wartość punktową na' & 'wartość punktu na'
# Found ngrams: 'wiadomo bardzo dużo' & 'wiadomo był największy'
# Found ngrams: 'widzę w bardzo' & 'widziała w byciu'
# Found ngrams: 'wiedzę i są' & 'wiedziała i bardzo'
# Found ngrams: 'wiedzę i są' & 'wiedziała i bardzo'
# Found ngrams: 'wiedzy nie był' & 'wiesz nie będziesz'
# Found ngrams: 'wiedzy nie były' & 'wiesz nie będziesz'
# Found ngrams: 'więcej niż mieści' & 'większe niż moi'
# Found ngrams: 'więcej niż moją' & 'większe niż moi'
# Found ngrams: 'więcej niż mieści' & 'więcej niż moją'
# Found ngrams: 'więcej niż mieści' & 'większe niż moi'
# Found ngrams: 'więcej zbrodni niż' & 'większej zbrodni niż'
# Found ngrams: 'wizja jest moją' & 'wizję będziesz miała'
# Found ngrams: 'wpadł w dużej' & 'wpadł w wielkiej'
# Found ngrams: 'wprowadzeniu wszystkich w' & 'wprowadziło wszystko w'
# Found ngrams: 'wszystkim bardzo mała' & 'wszystkim było mało'
# Found ngrams: 'wybrać się wczesnym' & 'wybrać się wcześnie'
# Found ngrams: 'wyciągają duże pieniądze' & 'wyciągają więcej pieniędzy'
# Found ngrams: 'wyjście to byłoby' & 'wyszło to bardzo'
# Found ngrams: 'wypowiedzianymi przez panią' & 'wypowiedziany przez pana'
# Found ngrams: 'wysokiego poziomu świadczeń' & 'wysokiego poziomu świadczonych'
# Found ngrams: 'wzorowe i wszyscy' & 'wzory i wszystko'
# Found ngrams: 'wzorowe i wszyscy' & 'wzory i wszystko'
# Found ngrams: 'w obozach warunki' & 'w obozowych warunkach'
# Found ngrams: 'w pełni uznajemy' & 'w pełni uznane'
# Found ngrams: 'zaczynali od klasy' & 'zaczynał od klasycznego'
# Found ngrams: 'zakupie tej firmy' & 'zakupową tej firmy'
# Found ngrams: 'zasadach miałyby być' & 'zasadzie miały bardzo'
# Found ngrams: 'zatem bardzo trudnego' & 'zatem jest trudny'
# Found ngrams: 'zawodami byłem tu' & 'zawodowe będą tu'
# Found ngrams: 'zawodowej i mam' & 'zawodu i mających'
# Found ngrams: 'za które miałam' & 'za którymi mój'
# Found ngrams: 'zbiegłych w roku' & 'zbiegł w latach'
# Found ngrams: 'zmniejsza zużycie wody' & 'zmniejszyło zużycie wody'
# Found ngrams: 'znają ten rodzaj' & 'znamy tę rodzinę'
# Found ngrams: 'została przyłączona w' & 'zostaną przyłącza w'
# Found ngrams: 'związkowym nie ma' & 'związku nie miałaby'
# Found ngrams: 'z człowiekiem poszłoby' & 'z ludem poszedł'
# Found ngrams: 'z działających za' & 'z działań za'
# Found ngrams: 'z panem rozmawia' & 'z panią rozmawiali'
# Found ngrams: 'żeby prawo stało' & 'żeby prawo stanowione'
# Found ngrams: 'że druga duża' & 'że drugą wielką'
# Found ngrams: 'że i klasę' & 'że i klasyczne'
# Found ngrams: 'że pan dużo' & 'że pan wielka'
# Found ngrams: 'że uznajemy tę' & 'że uznano to'
# Found ngrams: 'żyje źle i' & 'żył gorąca i'
